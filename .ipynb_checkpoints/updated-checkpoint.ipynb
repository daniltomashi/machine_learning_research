# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, auc, recall_score, precision_score, confusion_matrix, roc_auc_score, f1_score

# %%
benign = pd.read_csv("../data/benign.csv")
phisher = pd.read_csv("../data/phisher_data.csv")

# %%
benign.drop(["link", "letters_nums_in_link", "domain_name"], axis=1, inplace=True)
phisher.drop(["link", "letters_nums_in_link", "domain_name"], axis=1, inplace=True)

# %%
benign
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False         1.0          3
# 1                 0.0         False       False         0.5          1
# 2                 0.0         False       False         1.0          2
# 3                 0.0         False       False         0.5          2
# 4                 0.0         False       False         0.5          5
# ...               ...           ...         ...         ...        ...
# 2587              0.0         False       False         0.5          6
# 2588              0.0         False       False         1.0          8
# 2589              0.0         False       False         1.0          5
# 2590              0.0         False       False         1.0          4
# 2591              0.0         False       False         1.0          4
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False            False           False
# 1           False              False            False            True
# 2           False              False            False            True
# 3           False              False            False            True
# 4           False              False            False            True
# ...           ...                ...              ...             ...
# 2587        False              False            False            True
# 2588         True               True            False            True
# 2589        False              False             True           False
# 2590        False              False            False            True
# 2591        False              False            False            True
#
#       dash_in_domain  ...  no_hyperlink  internal_hyperlink_ratio  \
# 0              False  ...         False                         0
# 1              False  ...         False                         0
# 2              False  ...         False                         0
# 3              False  ...         False                         0
# 4              False  ...         False                         0
# ...              ...  ...           ...                       ...
# 2587           False  ...         False                         0
# 2588           False  ...         False                         0
# 2589           False  ...         False                         0
# 2590           False  ...         False                         0
# 2591           False  ...         False                         0
#
#       external_hyperlink_ratio  external_css  susp_form_link_action  \
# 0                            0          True                  False
# 1                            0          True                  False
# 2                            0          True                  False
# 3                            0          True                  False
# 4                            0          True                   True
# ...                        ...           ...                    ...
# 2587                         0          True                  False
# 2588                         0          True                  False
# 2589                         0          True                  False
# 2590                         0          True                  False
# 2591                         0          True                  False
#
#       anchor_null_links_answer  exist_of_extern_favicon  freq_of_most_anchor  \
# 0                        False                    False             0.021053
# 1                        False                     True             0.500000
# 2                        False                     True             0.022346
# 3                        False                     True             0.008368
# 4                        False                    False             0.036585
# ...                        ...                      ...                  ...
# 2587                     False                    False             0.034091
# 2588                     False                     True             0.014706
# 2589                     False                    False             0.020833
# 2590                     False                    False             0.007246
# 2591                     False                    False             0.007246
#
#       footer_value  sfh
# 0         0.058824    0
# 1         0.000000    0
# 2         0.083333    0
# 3         0.010204    0
# 4         0.058824    0
# ...            ...  ...
# 2587      0.000000    0
# 2588      0.016129    0
# 2589      0.066667    0
# 2590      0.500000    0
# 2591      0.500000    0
#
# [2592 rows x 24 columns]

# %%
phisher
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False           0          0
# 1                 0.0         False       False           0          0
# 2                 0.0         False       False           0          1
# 3                 0.0         False       False           0          1
# 4                 0.0         False       False           0          0
# ...               ...           ...         ...         ...        ...
# 2997              0.0         False       False           0          1
# 2998              0.0         False       False           0          1
# 2999              0.0         False       False           0          1
# 3000              0.0         False       False           0          1
# 3001              0.0         False       False           0          0
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False             True           False
# 1           False              False             True           False
# 2           False              False             True           False
# 3           False              False             True           False
# 4           False              False            False           False
# ...           ...                ...              ...             ...
# 2997        False              False             True           False
# 2998        False              False             True            True
# 2999        False              False             True           False
# 3000        False              False             True            True
# 3001        False              False            False           False
#
#       dash_in_domain  ...  no_hyperlink  internal_hyperlink_ratio  \
# 0              False  ...         False                         1
# 1              False  ...         False                         0
# 2               True  ...         False                         0
# 3              False  ...         False                         0
# 4              False  ...         False                         1
# ...              ...  ...           ...                       ...
# 2997           False  ...         False                         0
# 2998           False  ...         False                         1
# 2999           False  ...         False                         1
# 3000           False  ...         False                         0
# 3001           False  ...         False                         0
#
#       external_hyperlink_ratio  external_css  susp_form_link_action  \
# 0                            1         False                   True
# 1                            0          True                  False
# 2                            0          True                  False
# 3                            0          True                  False
# 4                            0          True                  False
# ...                        ...           ...                    ...
# 2997                         0          True                  False
# 2998                         1          True                  False
# 2999                         1          True                   True
# 3000                         0          True                  False
# 3001                         0          True                  False
#
#       anchor_null_links_answer  exist_of_extern_favicon  freq_of_most_anchor  \
# 0                        False                     True             0.058824
# 1                        False                    False             0.076923
# 2                        False                    False             0.202703
# 3                        False                    False             0.500000
# 4                        False                    False             1.000000
# ...                        ...                      ...                  ...
# 2997                     False                    False             0.012959
# 2998                     False                     True             0.019231
# 2999                     False                     True             0.021739
# 3000                     False                    False             0.027778
# 3001                     False                     True             0.007042
#
#       footer_value  sfh
# 0         0.000000  0.0
# 1         0.333333  0.0
# 2         1.000000  1.0
# 3         0.000000  0.0
# 4         0.000000  0.0
# ...            ...  ...
# 2997      0.250000  0.0
# 2998      0.000000  1.0
# 2999      0.031250  0.5
# 3000      0.000000  0.0
# 3001      0.000000  1.0
#
# [3002 rows x 24 columns]

# %% [markdown]
# # prepare data

# %%
phisher["phisher"] = 1
benign["phisher"] = 0

# %%
data = pd.concat([benign, phisher])

data
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False         1.0          3
# 1                 0.0         False       False         0.5          1
# 2                 0.0         False       False         1.0          2
# 3                 0.0         False       False         0.5          2
# 4                 0.0         False       False         0.5          5
# ...               ...           ...         ...         ...        ...
# 2997              0.0         False       False         0.0          1
# 2998              0.0         False       False         0.0          1
# 2999              0.0         False       False         0.0          1
# 3000              0.0         False       False         0.0          1
# 3001              0.0         False       False         0.0          0
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False            False           False
# 1           False              False            False            True
# 2           False              False            False            True
# 3           False              False            False            True
# 4           False              False            False            True
# ...           ...                ...              ...             ...
# 2997        False              False             True           False
# 2998        False              False             True            True
# 2999        False              False             True           False
# 3000        False              False             True            True
# 3001        False              False            False           False
#
#       dash_in_domain  ...  internal_hyperlink_ratio  external_hyperlink_ratio  \
# 0              False  ...                         0                         0
# 1              False  ...                         0                         0
# 2              False  ...                         0                         0
# 3              False  ...                         0                         0
# 4              False  ...                         0                         0
# ...              ...  ...                       ...                       ...
# 2997           False  ...                         0                         0
# 2998           False  ...                         1                         1
# 2999           False  ...                         1                         1
# 3000           False  ...                         0                         0
# 3001           False  ...                         0                         0
#
#       external_css  susp_form_link_action  anchor_null_links_answer  \
# 0             True                  False                     False
# 1             True                  False                     False
# 2             True                  False                     False
# 3             True                  False                     False
# 4             True                   True                     False
# ...            ...                    ...                       ...
# 2997          True                  False                     False
# 2998          True                  False                     False
# 2999          True                   True                     False
# 3000          True                  False                     False
# 3001          True                  False                     False
#
#       exist_of_extern_favicon  freq_of_most_anchor  footer_value  sfh  phisher
# 0                       False             0.021053      0.058824  0.0        0
# 1                        True             0.500000      0.000000  0.0        0
# 2                        True             0.022346      0.083333  0.0        0
# 3                        True             0.008368      0.010204  0.0        0
# 4                       False             0.036585      0.058824  0.0        0
# ...                       ...                  ...           ...  ...      ...
# 2997                    False             0.012959      0.250000  0.0        1
# 2998                     True             0.019231      0.000000  1.0        1
# 2999                     True             0.021739      0.031250  0.5        1
# 3000                    False             0.027778      0.000000  0.0        1
# 3001                     True             0.007042      0.000000  1.0        1
#
# [5594 rows x 25 columns]

# %%
data.corr()["phisher"].sort_values()
# Out:
# url_length                 -0.912598
# url_shortening             -0.714379
# url_depth                  -0.518040
# upper_case                 -0.351642
# external_css               -0.323235
# exist_of_extern_favicon    -0.322542
# http_https_domain          -0.071078
# redirection                -0.059171
# brand_names                -0.028619
# footer_value                0.010586
# dog_symbol                  0.044846
# sensetive_words             0.046792
# ip_in_domain                0.055660
# susp_form_link_action       0.065572
# count_subdomain             0.173973
# num_of_dots                 0.176471
# anchor_null_links_answer    0.220757
# external_hyperlink_ratio    0.277476
# no_hyperlink                0.280439
# sfh                         0.286303
# freq_of_most_anchor         0.286920
# dash_in_domain              0.351233
# internal_hyperlink_ratio    0.438057
# https_in_scheme             0.814159
# phisher                     1.000000
# Name: phisher, dtype: float64

# %%
data = data.drop("url_length", axis=1)

# %%
X, y = data.drop("phisher", axis=1).to_numpy(), data["phisher"].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
sns.countplot(x=y_test)
plt.title("Test data")
# Out:
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Test data')

# %% [markdown]
# # Test different models

# %%
from keras.layers import Dense, Dropout
from keras.models import Sequential

my_model = Sequential()
my_model.add(Dense(128, activation="relu", input_shape=(X_train.shape[-1],)))
my_model.add(Dropout(0.4))
my_model.add(Dense(64, activation="relu"))
my_model.add(Dense(32, activation="relu"))
my_model.add(Dense(1, activation="softmax"))

my_model.compile("adam", loss="binary_crossentropy")


# fit and predict
model.fit(np.asarray(X_train).astype('float32'), y_train)
y_test_pred = model.predict(np.asarray(X_test).astype('float32'))

scores = [f"{metric.__name__} --> {metric(y_test, y_test_pred)}" \
                 for metric in [accuracy_score, recall_score, precision_score, roc_auc_score, f1_score]]

print('\n'.join(scores))
# Out:
# 140/140 [==============================] - 0s 875us/step - loss: 0.0343
# 35/35 [==============================] - 0s 606us/step
# accuracy_score --> 0.516532618409294
# recall_score --> 1.0
# precision_score --> 0.516532618409294
# roc_auc_score --> 0.5
# f1_score --> 0.6812021213906895

# %%
models = [LogisticRegression(solver='lbfgs', C=1.0, max_iter=100, penalty='l2'),
          DecisionTreeClassifier(criterion='gini', max_depth=5),
          SVC(kernel='linear', C=10, random_state=12),
          RandomForestClassifier(n_estimators=10, random_state=42),
          XGBClassifier(learning_rate=0.4, max_depth=5),
          my_model]


roc = []
for model in models:
    model.fit(np.asarray(X_train).astype('float32'), y_train)
    y_test_pred = model.predict(np.asarray(X_test).astype('float32'))
    
    TN = sum((y_test == 0) & (y_test_pred == 0))
    FP = sum((y_test == 0) & (y_test_pred == 1))
    TP = sum((y_test == 1) & (y_test_pred == 1))
    FN = sum((y_test == 1) & (y_test_pred == 0))
    
    FPR = FP/(TN+FP)
    TPR = TP/(TP+FN)
    
    scores = [f"{metric.__name__} --> {metric(y_test, y_test_pred)}" \
                     for metric in [accuracy_score, recall_score, precision_score, roc_auc_score, f1_score]]
    
    print(model.__class__.__name__)
    print()
    print('\n'.join(scores))
    print("False positive rate -->", FPR)
    print('-'*100)
    
    scores = [score.split(' --> ') for score in scores]
    X_plot, y_plot = [score[0] for score in scores]+["False positive rate"], [float(score[1]) for score in scores]+[FPR]
    
    fig, ax = plt.subplots()
    sns.barplot(x=X_plot, y=y_plot)
    plt.title(model.__class__.__name__)
    
    
#     fpr, tpr, thresholds = roc_curve(y_test, y_test_pred)
    roc_auc = roc_auc_score(y_test, y_test_pred)
    
#     roc.append([model.__class__.__name__, fpr, tpr, roc_auc])
    roc.append([model.__class__.__name__, roc_auc])

    
# plt.figure(figsize=(20,10))
# for i in roc:
#     plt.plot([j for j in i[1]], [j for j in i[2]], color='darkorange', lw=2, label=f'ROC curve (area = {i[3]:.2f})')
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.legend(loc='lower right')
    
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
# plt.legend([i[0] for i in roc])
# Out:
# LogisticRegression
#
# accuracy_score --> 0.9848078641644326
# recall_score --> 0.9844290657439446
# precision_score --> 0.9861351819757366
# roc_auc_score --> 0.9848208175300129
# f1_score --> 0.9852813852813853
# False positive rate --> 0.014787430683918669
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier
#
# accuracy_score --> 0.9883824843610366
# recall_score --> 0.9844290657439446
# precision_score --> 0.9930191972076788
# roc_auc_score --> 0.9885176752009925
# f1_score --> 0.9887054735013031
# False positive rate --> 0.0073937153419593345
# ----------------------------------------------------------------------------------------------------
# SVC
#
# accuracy_score --> 0.9883824843610366
# recall_score --> 0.9844290657439446
# precision_score --> 0.9930191972076788
# roc_auc_score --> 0.9885176752009925
# f1_score --> 0.9887054735013031
# False positive rate --> 0.0073937153419593345
# ----------------------------------------------------------------------------------------------------
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# RandomForestClassifier
#
# accuracy_score --> 0.9937444146559428
# recall_score --> 0.9930795847750865
# precision_score --> 0.9948006932409013
# roc_auc_score --> 0.9937671491343085
# f1_score --> 0.993939393939394
# False positive rate --> 0.005545286506469501
# ----------------------------------------------------------------------------------------------------
# XGBClassifier
#
# accuracy_score --> 0.9946380697050938
# recall_score --> 0.9948096885813149
# precision_score --> 0.9948096885813149
# roc_auc_score --> 0.9946322010374228
# f1_score --> 0.994809688581315
# False positive rate --> 0.005545286506469501
# ----------------------------------------------------------------------------------------------------
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1478: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# 140/140 [==============================] - 1s 902us/step - loss: 0.1970
# 35/35 [==============================] - 0s 645us/step
# Sequential
#
# accuracy_score --> 0.516532618409294
# recall_score --> 1.0
# precision_score --> 0.516532618409294
# roc_auc_score --> 0.5
# f1_score --> 0.6812021213906895
# False positive rate --> [nan nan nan ...  1.  1. nan]
# ----------------------------------------------------------------------------------------------------
# /tmp/ipykernel_77780/849453603.py:19: RuntimeWarning: invalid value encountered in divide
#   FPR = FP/(TN+FP)
# /tmp/ipykernel_77780/849453603.py:20: RuntimeWarning: invalid value encountered in divide
#   TPR = TP/(TP+FN)
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/danylo/.local/lib/python3.10/site-packages/seaborn/_core.py:1218: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 35
#      32     X_plot, y_plot = [score[0] for score in scores]+["False positive rate"], [float(score[1]) for score in scores]+[FPR]
#      34     fig, ax = plt.subplots()
# ---> 35     sns.barplot(x=X_plot, y=y_plot)
#      36     plt.title(model.__class__.__name__)
#      39 #     fpr, tpr, thresholds = roc_curve(y_test, y_test_pred)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:3179, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3166 @_deprecate_positional_args
#    3167 def barplot(
#    3168     *,
#    (...)
#    3176     **kwargs,
#    3177 ):
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
#    3182                           errcolor, errwidth, capsize, dodge)
#    3184     if ax is None:
#    3185         ax = plt.gca()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:1584, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1579 def __init__(self, x, y, hue, data, order, hue_order,
#    1580              estimator, ci, n_boot, units, seed,
#    1581              orient, color, palette, saturation, errcolor,
#    1582              errwidth, capsize, dodge):
#    1583     """Initialize the plotter."""
# -> 1584     self.establish_variables(x, y, hue, data, orient,
#    1585                              order, hue_order, units)
#    1586     self.establish_colors(color, palette, saturation)
#    1587     self.estimate_statistic(estimator, ci, n_boot, seed)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:156, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153         raise ValueError(err)
#     155 # Figure out the plotting orientation
# --> 156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#     160 # Option 2a:
#     161 # We are plotting a single set of data
#     162 # ------------------------------------
#     163 if x is None or y is None:
#     164
#     165     # Determine where the data are
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_core.py:1305, in infer_orient(x, y, orient, require_numeric)
#    1277 """Determine how the plot should be oriented based on the data.
#    1278
#    1279 For historical reasons, the convention is to call a plot "horizontally"
#    (...)
#    1301
#    1302 """
#    1304 x_type = None if x is None else variable_type(x)
# -> 1305 y_type = None if y is None else variable_type(y)
#    1307 nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#    1308 single_var_warning = "{} orientation ignored with only `{}` specified."
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_core.py:1237, in variable_type(vector, boolean_type)
#    1233 with warnings.catch_warnings():
#    1234     warnings.simplefilter(
#    1235         action='ignore', category=(FutureWarning, DeprecationWarning)
#    1236     )
# -> 1237     if np.isin(vector, [0, 1, np.nan]).all():
#    1238         return boolean_type
#    1240 # Defer to positive pandas tests
#
# File <__array_function__ internals>:200, in isin(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:889, in isin(element, test_elements, assume_unique, invert, kind)
#     766 @array_function_dispatch(_isin_dispatcher)
#     767 def isin(element, test_elements, assume_unique=False, invert=False, *,
#     768          kind=None):
#     769     """
#     770     Calculates ``element in test_elements``, broadcasting over `element` only.
#     771     Returns a boolean array of the same shape as `element` that is True
#    (...)
#     887            [ True, False]])
#     888     """
# --> 889     element = np.asarray(element)
#     890     return in1d(element, test_elements, assume_unique=assume_unique,
#     891                 invert=invert, kind=kind).reshape(element.shape)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.

# %% [markdown]
# # different features

# %%
X_url = data[data.columns[:13]]
X_hyperlink = data[data.columns[13:]]

# %%
X_url_train, X_url_test, y_url_train, y_url_test = train_test_split(X_url, y)
X_hyperlink_train, X_hyperlink_test, y_hyperlink_train, y_hyperlink_test = train_test_split(X_hyperlink, y)

# %%
model_url = XGBClassifier(learning_rate=0.4, max_depth=5)
model_hyperlink = XGBClassifier(learning_rate=0.4, max_depth=5)

# %%
model_url.fit(X_url_train, y_url_train)
model_hyperlink.fit(X_hyperlink_train, y_hyperlink_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
fig = plt.figure(figsize=(20,10))

print(model_url.score(X_url_test, y_url_test))
print(model_hyperlink.score(X_hyperlink_test, y_hyperlink_test))

plt.bar(x=["url", "hyperlink"], height=[model_url.score(X_url_test, y_url_test), model_hyperlink.score(X_hyperlink_test, y_hyperlink_test)])
# Out:
# 0.9792709077912795
# 1.0
# <BarContainer object of 2 artists>
