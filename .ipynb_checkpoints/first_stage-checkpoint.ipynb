# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, auc, recall_score, precision_score, confusion_matrix, roc_auc_score

# %%
benign = pd.read_csv("../data/benign.csv")
phisher = pd.read_csv("../data/phisher_data.csv")

# %%
benign.drop(["link", "letters_nums_in_link", "domain_name"], axis=1, inplace=True)
phisher.drop(["link", "letters_nums_in_link", "domain_name"], axis=1, inplace=True)

# %%
benign
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False         1.0          3
# 1                 0.0         False       False         0.5          1
# 2                 0.0         False       False         1.0          2
# 3                 0.0         False       False         0.5          2
# 4                 0.0         False       False         0.5          5
# ...               ...           ...         ...         ...        ...
# 2587              0.0         False       False         0.5          6
# 2588              0.0         False       False         1.0          8
# 2589              0.0         False       False         1.0          5
# 2590              0.0         False       False         1.0          4
# 2591              0.0         False       False         1.0          4
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False            False           False
# 1           False              False            False            True
# 2           False              False            False            True
# 3           False              False            False            True
# 4           False              False            False            True
# ...           ...                ...              ...             ...
# 2587        False              False            False            True
# 2588         True               True            False            True
# 2589        False              False             True           False
# 2590        False              False            False            True
# 2591        False              False            False            True
#
#       dash_in_domain  ...  no_hyperlink  internal_hyperlink_ratio  \
# 0              False  ...         False                         0
# 1              False  ...         False                         0
# 2              False  ...         False                         0
# 3              False  ...         False                         0
# 4              False  ...         False                         0
# ...              ...  ...           ...                       ...
# 2587           False  ...         False                         0
# 2588           False  ...         False                         0
# 2589           False  ...         False                         0
# 2590           False  ...         False                         0
# 2591           False  ...         False                         0
#
#       external_hyperlink_ratio  external_css  susp_form_link_action  \
# 0                            0          True                  False
# 1                            0          True                  False
# 2                            0          True                  False
# 3                            0          True                  False
# 4                            0          True                   True
# ...                        ...           ...                    ...
# 2587                         0          True                  False
# 2588                         0          True                  False
# 2589                         0          True                  False
# 2590                         0          True                  False
# 2591                         0          True                  False
#
#       anchor_null_links_answer  exist_of_extern_favicon  freq_of_most_anchor  \
# 0                        False                    False             0.021053
# 1                        False                     True             0.500000
# 2                        False                     True             0.022346
# 3                        False                     True             0.008368
# 4                        False                    False             0.036585
# ...                        ...                      ...                  ...
# 2587                     False                    False             0.034091
# 2588                     False                     True             0.014706
# 2589                     False                    False             0.020833
# 2590                     False                    False             0.007246
# 2591                     False                    False             0.007246
#
#       footer_value  sfh
# 0         0.058824    0
# 1         0.000000    0
# 2         0.083333    0
# 3         0.010204    0
# 4         0.058824    0
# ...            ...  ...
# 2587      0.000000    0
# 2588      0.016129    0
# 2589      0.066667    0
# 2590      0.500000    0
# 2591      0.500000    0
#
# [2592 rows x 24 columns]

# %%
phisher
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False           0          0
# 1                 0.0         False       False           0          0
# 2                 0.0         False       False           0          1
# 3                 0.0         False       False           0          1
# 4                 0.0         False       False           0          0
# ...               ...           ...         ...         ...        ...
# 2997              0.0         False       False           0          1
# 2998              0.0         False       False           0          1
# 2999              0.0         False       False           0          1
# 3000              0.0         False       False           0          1
# 3001              0.0         False       False           0          0
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False             True           False
# 1           False              False             True           False
# 2           False              False             True           False
# 3           False              False             True           False
# 4           False              False            False           False
# ...           ...                ...              ...             ...
# 2997        False              False             True           False
# 2998        False              False             True            True
# 2999        False              False             True           False
# 3000        False              False             True            True
# 3001        False              False            False           False
#
#       dash_in_domain  ...  no_hyperlink  internal_hyperlink_ratio  \
# 0              False  ...         False                         1
# 1              False  ...         False                         0
# 2               True  ...         False                         0
# 3              False  ...         False                         0
# 4              False  ...         False                         1
# ...              ...  ...           ...                       ...
# 2997           False  ...         False                         0
# 2998           False  ...         False                         1
# 2999           False  ...         False                         1
# 3000           False  ...         False                         0
# 3001           False  ...         False                         0
#
#       external_hyperlink_ratio  external_css  susp_form_link_action  \
# 0                            1         False                   True
# 1                            0          True                  False
# 2                            0          True                  False
# 3                            0          True                  False
# 4                            0          True                  False
# ...                        ...           ...                    ...
# 2997                         0          True                  False
# 2998                         1          True                  False
# 2999                         1          True                   True
# 3000                         0          True                  False
# 3001                         0          True                  False
#
#       anchor_null_links_answer  exist_of_extern_favicon  freq_of_most_anchor  \
# 0                        False                     True             0.058824
# 1                        False                    False             0.076923
# 2                        False                    False             0.202703
# 3                        False                    False             0.500000
# 4                        False                    False             1.000000
# ...                        ...                      ...                  ...
# 2997                     False                    False             0.012959
# 2998                     False                     True             0.019231
# 2999                     False                     True             0.021739
# 3000                     False                    False             0.027778
# 3001                     False                     True             0.007042
#
#       footer_value  sfh
# 0         0.000000  0.0
# 1         0.333333  0.0
# 2         1.000000  1.0
# 3         0.000000  0.0
# 4         0.000000  0.0
# ...            ...  ...
# 2997      0.250000  0.0
# 2998      0.000000  1.0
# 2999      0.031250  0.5
# 3000      0.000000  0.0
# 3001      0.000000  1.0
#
# [3002 rows x 24 columns]

# %% [markdown]
# # prepare data

# %%
phisher["phisher"] = 1
benign["phisher"] = 0

# %%
data = pd.concat([benign, phisher])

data
# Out:
#       count_subdomain  ip_in_domain  dog_symbol  url_length  url_depth  \
# 0                 0.0         False       False         1.0          3
# 1                 0.0         False       False         0.5          1
# 2                 0.0         False       False         1.0          2
# 3                 0.0         False       False         0.5          2
# 4                 0.0         False       False         0.5          5
# ...               ...           ...         ...         ...        ...
# 2997              0.0         False       False         0.0          1
# 2998              0.0         False       False         0.0          1
# 2999              0.0         False       False         0.0          1
# 3000              0.0         False       False         0.0          1
# 3001              0.0         False       False         0.0          0
#
#       redirection  http_https_domain  https_in_scheme  url_shortening  \
# 0           False              False            False           False
# 1           False              False            False            True
# 2           False              False            False            True
# 3           False              False            False            True
# 4           False              False            False            True
# ...           ...                ...              ...             ...
# 2997        False              False             True           False
# 2998        False              False             True            True
# 2999        False              False             True           False
# 3000        False              False             True            True
# 3001        False              False            False           False
#
#       dash_in_domain  ...  internal_hyperlink_ratio  external_hyperlink_ratio  \
# 0              False  ...                         0                         0
# 1              False  ...                         0                         0
# 2              False  ...                         0                         0
# 3              False  ...                         0                         0
# 4              False  ...                         0                         0
# ...              ...  ...                       ...                       ...
# 2997           False  ...                         0                         0
# 2998           False  ...                         1                         1
# 2999           False  ...                         1                         1
# 3000           False  ...                         0                         0
# 3001           False  ...                         0                         0
#
#       external_css  susp_form_link_action  anchor_null_links_answer  \
# 0             True                  False                     False
# 1             True                  False                     False
# 2             True                  False                     False
# 3             True                  False                     False
# 4             True                   True                     False
# ...            ...                    ...                       ...
# 2997          True                  False                     False
# 2998          True                  False                     False
# 2999          True                   True                     False
# 3000          True                  False                     False
# 3001          True                  False                     False
#
#       exist_of_extern_favicon  freq_of_most_anchor  footer_value  sfh  phisher
# 0                       False             0.021053      0.058824  0.0        0
# 1                        True             0.500000      0.000000  0.0        0
# 2                        True             0.022346      0.083333  0.0        0
# 3                        True             0.008368      0.010204  0.0        0
# 4                       False             0.036585      0.058824  0.0        0
# ...                       ...                  ...           ...  ...      ...
# 2997                    False             0.012959      0.250000  0.0        1
# 2998                     True             0.019231      0.000000  1.0        1
# 2999                     True             0.021739      0.031250  0.5        1
# 3000                    False             0.027778      0.000000  0.0        1
# 3001                     True             0.007042      0.000000  1.0        1
#
# [5594 rows x 25 columns]

# %%
data.corr()
# Out:
#                           count_subdomain  ip_in_domain  dog_symbol  \
# count_subdomain                  1.000000      0.259488    0.051919
# ip_in_domain                     0.259488      1.000000    0.059310
# dog_symbol                       0.051919      0.059310    1.000000
# url_length                      -0.158345     -0.050795   -0.040927
# url_depth                       -0.080645     -0.042092   -0.000843
# redirection                     -0.014035     -0.006595   -0.005314
# http_https_domain               -0.016372     -0.007169   -0.005776
# https_in_scheme                  0.070043     -0.043810    0.036904
# url_shortening                  -0.117160     -0.052996   -0.034786
# dash_in_domain                   0.098506     -0.023787    0.002480
# sensetive_words                  0.040074      0.026531    0.059950
# brand_names                      0.108469     -0.008325    0.020522
# upper_case                      -0.021988     -0.029641    0.012512
# num_of_dots                      0.484710      0.144918    0.101945
# no_hyperlink                     0.150185      0.046888    0.079385
# internal_hyperlink_ratio         0.150513      0.028993    0.053912
# external_hyperlink_ratio         0.021651     -0.003521    0.000722
# external_css                    -0.161392     -0.053165   -0.060104
# susp_form_link_action            0.038210     -0.017781   -0.014327
# anchor_null_links_answer         0.043964     -0.014534   -0.011710
# exist_of_extern_favicon         -0.089912     -0.057504   -0.045951
# freq_of_most_anchor              0.014214      0.002039    0.012924
# footer_value                    -0.041211     -0.024943   -0.020279
# sfh                              0.054191     -0.006711   -0.000311
# phisher                          0.173973      0.055660    0.044846
#
#                           url_length  url_depth  redirection  \
# count_subdomain            -0.158345  -0.080645    -0.014035
# ip_in_domain               -0.050795  -0.042092    -0.006595
# dog_symbol                 -0.040927  -0.000843    -0.005314
# url_length                  1.000000   0.376115     0.060762
# url_depth                   0.376115   1.000000     0.331311
# redirection                 0.060762   0.331311     1.000000
# http_https_domain           0.064284   0.282050     0.822436
# https_in_scheme            -0.751871  -0.381198    -0.046590
# url_shortening              0.651951   0.378411     0.042539
# dash_in_domain             -0.322335  -0.200664    -0.029351
# sensetive_words            -0.037578  -0.027289     0.001562
# brand_names                 0.011425   0.071213     0.020856
# upper_case                  0.445917   0.039275     0.077542
# num_of_dots                -0.156820   0.076459     0.224341
# no_hyperlink               -0.255928  -0.098167    -0.003525
# internal_hyperlink_ratio   -0.418778  -0.131890     0.001129
# external_hyperlink_ratio   -0.273415  -0.067805     0.007706
# external_css                0.300033   0.060172     0.013216
# susp_form_link_action      -0.082312  -0.004862    -0.032683
# anchor_null_links_answer   -0.201994  -0.132329    -0.012370
# exist_of_extern_favicon     0.346180  -0.021649     0.042855
# freq_of_most_anchor        -0.266577  -0.122862     0.031303
# footer_value               -0.031281   0.016135    -0.039614
# sfh                        -0.261280  -0.162714    -0.033924
# phisher                    -0.912598  -0.518040    -0.059171
#
#                           http_https_domain  https_in_scheme  url_shortening  \
# count_subdomain                   -0.016372         0.070043       -0.117160
# ip_in_domain                      -0.007169        -0.043810       -0.052996
# dog_symbol                        -0.005776         0.036904       -0.034786
# url_length                         0.064284        -0.751871        0.651951
# url_depth                          0.282050        -0.381198        0.378411
# redirection                        0.822436        -0.046590        0.042539
# http_https_domain                  1.000000        -0.023444        0.051429
# https_in_scheme                   -0.023444         1.000000       -0.640382
# url_shortening                     0.051429        -0.640382        1.000000
# dash_in_domain                    -0.029862         0.280902       -0.265961
# sensetive_words                    0.016900         0.060072       -0.013783
# brand_names                        0.027813        -0.034876        0.029025
# upper_case                         0.087757        -0.288270        0.263023
# num_of_dots                        0.235579         0.124469       -0.122043
# no_hyperlink                      -0.014213         0.224094       -0.271020
# internal_hyperlink_ratio           0.020851         0.324636       -0.246920
# external_hyperlink_ratio           0.037260         0.203771       -0.086775
# external_css                       0.024998        -0.224215        0.247784
# susp_form_link_action              0.003347         0.057090        0.022123
# anchor_null_links_answer          -0.022427         0.152434       -0.196686
# exist_of_extern_favicon            0.050725        -0.226693        0.302288
# freq_of_most_anchor                0.014998         0.188101       -0.181248
# footer_value                      -0.035742         0.030626        0.016969
# sfh                               -0.030935         0.249113       -0.171445
# phisher                           -0.071078         0.814159       -0.714379
#
#                           dash_in_domain  ...  internal_hyperlink_ratio  \
# count_subdomain                 0.098506  ...                  0.150513
# ip_in_domain                   -0.023787  ...                  0.028993
# dog_symbol                      0.002480  ...                  0.053912
# url_length                     -0.322335  ...                 -0.418778
# url_depth                      -0.200664  ...                 -0.131890
# redirection                    -0.029351  ...                  0.001129
# http_https_domain              -0.029862  ...                  0.020851
# https_in_scheme                 0.280902  ...                  0.324636
# url_shortening                 -0.265961  ...                 -0.246920
# dash_in_domain                  1.000000  ...                  0.182072
# sensetive_words                 0.038293  ...                  0.028425
# brand_names                     0.017433  ...                  0.001969
# upper_case                     -0.168434  ...                 -0.194550
# num_of_dots                     0.104174  ...                  0.168941
# no_hyperlink                    0.174060  ...                  0.436378
# internal_hyperlink_ratio        0.182072  ...                  1.000000
# external_hyperlink_ratio        0.076074  ...                  0.778012
# external_css                   -0.143987  ...                 -0.488465
# susp_form_link_action           0.021574  ...                  0.027211
# anchor_null_links_answer        0.085599  ...                 -0.007717
# exist_of_extern_favicon        -0.146798  ...                 -0.239934
# freq_of_most_anchor             0.075039  ...                  0.180450
# footer_value                    0.010129  ...                 -0.082502
# sfh                             0.042168  ...                  0.106837
# phisher                         0.351233  ...                  0.438057
#
#                           external_hyperlink_ratio  external_css  \
# count_subdomain                           0.021651     -0.161392
# ip_in_domain                             -0.003521     -0.053165
# dog_symbol                                0.000722     -0.060104
# url_length                               -0.273415      0.300033
# url_depth                                -0.067805      0.060172
# redirection                               0.007706      0.013216
# http_https_domain                         0.037260      0.024998
# https_in_scheme                           0.203771     -0.224215
# url_shortening                           -0.086775      0.247784
# dash_in_domain                            0.076074     -0.143987
# sensetive_words                           0.037764     -0.010061
# brand_names                              -0.018224      0.006203
# upper_case                               -0.200415      0.097309
# num_of_dots                               0.029797     -0.165865
# no_hyperlink                             -0.162397     -0.609335
# internal_hyperlink_ratio                  0.778012     -0.488465
# external_hyperlink_ratio                  1.000000     -0.134182
# external_css                             -0.134182      1.000000
# susp_form_link_action                     0.080545      0.097600
# anchor_null_links_answer                  0.019019      0.031906
# exist_of_extern_favicon                  -0.009354      0.381470
# freq_of_most_anchor                       0.273855     -0.015916
# footer_value                             -0.003771      0.117648
# sfh                                       0.146708      0.038920
# phisher                                   0.277476     -0.323235
#
#                           susp_form_link_action  anchor_null_links_answer  \
# count_subdomain                        0.038210                  0.043964
# ip_in_domain                          -0.017781                 -0.014534
# dog_symbol                            -0.014327                 -0.011710
# url_length                            -0.082312                 -0.201994
# url_depth                             -0.004862                 -0.132329
# redirection                           -0.032683                 -0.012370
# http_https_domain                      0.003347                 -0.022427
# https_in_scheme                        0.057090                  0.152434
# url_shortening                         0.022123                 -0.196686
# dash_in_domain                         0.021574                  0.085599
# sensetive_words                        0.022144                 -0.021750
# brand_names                            0.016418                  0.023499
# upper_case                             0.010164                 -0.110477
# num_of_dots                           -0.018758                 -0.009166
# no_hyperlink                          -0.087219                 -0.073226
# internal_hyperlink_ratio               0.027211                 -0.007717
# external_hyperlink_ratio               0.080545                  0.019019
# external_css                           0.097600                  0.031906
# susp_form_link_action                  1.000000                  0.079545
# anchor_null_links_answer               0.079545                  1.000000
# exist_of_extern_favicon                0.049357                 -0.031778
# freq_of_most_anchor                   -0.038756                  0.211578
# footer_value                           0.033030                  0.080262
# sfh                                    0.195075                  0.139411
# phisher                                0.065572                  0.220757
#
#                           exist_of_extern_favicon  freq_of_most_anchor  \
# count_subdomain                         -0.089912             0.014214
# ip_in_domain                            -0.057504             0.002039
# dog_symbol                              -0.045951             0.012924
# url_length                               0.346180            -0.266577
# url_depth                               -0.021649            -0.122862
# redirection                              0.042855             0.031303
# http_https_domain                        0.050725             0.014998
# https_in_scheme                         -0.226693             0.188101
# url_shortening                           0.302288            -0.181248
# dash_in_domain                          -0.146798             0.075039
# sensetive_words                         -0.008937             0.144941
# brand_names                              0.025960            -0.015526
# upper_case                               0.259329            -0.076296
# num_of_dots                             -0.085374             0.091782
# no_hyperlink                            -0.382846            -0.132369
# internal_hyperlink_ratio                -0.239934             0.180450
# external_hyperlink_ratio                -0.009354             0.273855
# external_css                             0.381470            -0.015916
# susp_form_link_action                    0.049357            -0.038756
# anchor_null_links_answer                -0.031778             0.211578
# exist_of_extern_favicon                  1.000000            -0.172892
# freq_of_most_anchor                     -0.172892             1.000000
# footer_value                            -0.041913            -0.027368
# sfh                                      0.007853             0.004815
# phisher                                 -0.322542             0.286920
#
#                           footer_value       sfh   phisher
# count_subdomain              -0.041211  0.054191  0.173973
# ip_in_domain                 -0.024943 -0.006711  0.055660
# dog_symbol                   -0.020279 -0.000311  0.044846
# url_length                   -0.031281 -0.261280 -0.912598
# url_depth                     0.016135 -0.162714 -0.518040
# redirection                  -0.039614 -0.033924 -0.059171
# http_https_domain            -0.035742 -0.030935 -0.071078
# https_in_scheme               0.030626  0.249113  0.814159
# url_shortening                0.016969 -0.171445 -0.714379
# dash_in_domain                0.010129  0.042168  0.351233
# sensetive_words              -0.032951 -0.002567  0.046792
# brand_names                   0.018076 -0.009399 -0.028619
# upper_case                   -0.110054 -0.135046 -0.351642
# num_of_dots                  -0.101061  0.000200  0.176471
# no_hyperlink                 -0.128145 -0.084120  0.280439
# internal_hyperlink_ratio     -0.082502  0.106837  0.438057
# external_hyperlink_ratio     -0.003771  0.146708  0.277476
# external_css                  0.117648  0.038920 -0.323235
# susp_form_link_action         0.033030  0.195075  0.065572
# anchor_null_links_answer      0.080262  0.139411  0.220757
# exist_of_extern_favicon      -0.041913  0.007853 -0.322542
# freq_of_most_anchor          -0.027368  0.004815  0.286920
# footer_value                  1.000000  0.104891  0.010586
# sfh                           0.104891  1.000000  0.286303
# phisher                       0.010586  0.286303  1.000000
#
# [25 rows x 25 columns]

# %%
X, y = data.drop("phisher", axis=1).to_numpy(), data["phisher"].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
sns.countplot(x=y_test)
plt.title("Test data")
# Out:
# Text(0.5, 1.0, 'Test data')

# %% [markdown]
# # Test different models

# %%
models = [LogisticRegression(solver='lbfgs', C=1.0, max_iter=100, penalty='l2'),
          DecisionTreeClassifier(criterion='gini', max_depth=5),
          SVC(kernel='linear', C=10, random_state=12),
          RandomForestClassifier(n_estimators=10, random_state=42)]


roc = []
for model in models:
    model.fit(X_train, y_train)
    y_test_pred = model.predict(X_test)
    
    TN = sum((y_test == 0) & (y_test_pred == 0))
    FP = sum((y_test == 0) & (y_test_pred == 1))
    TP = sum((y_test == 1) & (y_test_pred == 1))
    FN = sum((y_test == 1) & (y_test_pred == 0))
    
    FPR = FP/(TN+FP)
    TPR = TP/(TP+FN)
    
    scores = [f"{metric.__name__} --> {metric(y_test, y_test_pred)}" \
                     for metric in [accuracy_score, recall_score, precision_score, roc_auc_score]]
    
    print(model.__class__.__name__)
    print()
    print('\n'.join(scores))
    print("False positive rate -->", FPR)
    print('-'*100)
    
    scores = [score.split(' --> ') for score in scores]
    X_plot, y_plot = [score[0] for score in scores]+["False positive rate"], [float(score[1]) for score in scores]+[FPR]
    
    fig, ax = plt.subplots()
    sns.barplot(x=X_plot, y=y_plot)
    plt.title(model.__class__.__name__)
    
    
    fpr, tpr, thresholds = roc_curve(y_test, y_test_pred)
    roc_auc = roc_auc_score(y_test, y_test_pred)
    
    roc.append([model.__class__.__name__, fpr, tpr, roc_auc])

    
plt.figure(figsize=(20,10))
for i in roc:
    plt.plot([j for j in i[1]], [j for j in i[2]], color='darkorange', lw=2, label=f'ROC curve (area = {i[3]:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.legend(loc='lower right')
    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
plt.legend([i[0] for i in roc])
# Out:
# LogisticRegression
#
# accuracy_score --> 1.0
# recall_score --> 1.0
# precision_score --> 1.0
# roc_auc_score --> 1.0
# False positive rate --> 0.0
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier
#
# accuracy_score --> 1.0
# recall_score --> 1.0
# precision_score --> 1.0
# roc_auc_score --> 1.0
# False positive rate --> 0.0
# ----------------------------------------------------------------------------------------------------
# SVC
#
# accuracy_score --> 1.0
# recall_score --> 1.0
# precision_score --> 1.0
# roc_auc_score --> 1.0
# False positive rate --> 0.0
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier
#
# accuracy_score --> 1.0
# recall_score --> 1.0
# precision_score --> 1.0
# roc_auc_score --> 1.0
# False positive rate --> 0.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # different features

# %%
X_url = data[data.columns[:14]]
X_hyperlink = data[data.columns[14:]]

# %%
X_url_train, X_url_test, y_url_train, y_url_test = train_test_split(X_url, y)
X_hyperlink_train, X_hyperlink_test, y_hyperlink_train, y_hyperlink_test = train_test_split(X_hyperlink, y)

# %%
model_url = DecisionTreeClassifier(criterion='gini', max_depth=5)
model_hyperlink = DecisionTreeClassifier(criterion='gini', max_depth=5)

# %%
model_url.fit(X_url_train, y_url_train)
model_hyperlink.fit(X_hyperlink_train, y_hyperlink_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
fig = plt.figure(figsize=(20,10))

plt.bar(x=["url", "hyperlink"], height=[model_url.score(X_url_test, y_url_test), model_hyperlink.score(X_hyperlink_test, y_hyperlink_test)])
# Out:
# <BarContainer object of 2 artists>
